# %% [markdown]
# # Notebook Valentin

# %%
import pandas as pd

# %% [markdown]
# ##  Intro

# %% [markdown]
# ### SAA t-1
# Let's say we are at time t, we have our fifty states for which we want to prescribe tests with SAA using information of tests sold in time t-1.
# Two approches:
# - scalar: for a state, take the average on all states for previous time
# - vector: points are now vector in dimensions R^50 (for 50 states for instance). Take the vector average, which basicaly mean as we only have a single vector - the one for t-1 - to take exactly the same info as t-1 for each state
#
# Observe: for scalar: all states will prescribe the same value, namely the average for t-1, whereas it's not the case for vector SAA.
#
#
# ### SAA cumulative
#
# Again there are the two approches:
# - scalar: for each state take the average for all states on all previous step. Again all prescription will thus be the same
# - vector: vector average, i.e. here for a given state take the average on all previous step of test stold FOR THIS GIVEN state

# %% [markdown]
# ## SAA t-1: SAA prescription with training data from t-1 only

# %%
data = pd.read_csv('data/final_df_drop.csv')
data.head()
# Out:
#      State        Date  population  confirmed  deaths  incident_rate  \
# 0  Alabama  2020-04-12   4903185.0       3563      93          75.99
# 1  Alabama  2020-04-13   4903185.0       3734      99          79.63
# 2  Alabama  2020-04-14   4903185.0       3953     114          84.31
# 3  Alabama  2020-04-15   4903185.0       4075     118          86.91
# 4  Alabama  2020-04-16   4903185.0       4345     133          92.67
#
#    mortality_rate  testing_rate  TestsReported
# 0            2.61        460.30           2165
# 1            2.65        622.36           2626
# 2            2.88        706.29           2942
# 3            2.90        726.76           3289
# 4            3.06        776.11           3079

# %%
# Sort by date
data.sort_values(by='Date', inplace=True)

# %%
data.shape
# Out:
# (7176, 9)

# %%
### df for SAA t-1 prescription

# Scalar SAA t-1

SAA_1 = data[['State', 'Date', 'TestsReported']]
# Shift Date to compute the average on t-1
SAA_1['Date'] = pd.to_datetime(SAA_1['Date'])
SAA_1['Shift_Date'] = SAA_1['Date'] + pd.Timedelta(days=1)
average = SAA_1.groupby('Shift_Date')['TestsReported'].mean().round().rename('SAA_t_1_scalar')
# Merge df and averages
SAA_1 = SAA_1.merge(average, left_on='Date', right_on='Shift_Date', how='left')
SAA_1
# Out:
# /var/folders/m7/tssqlvyd6qg7dyx5bvdn0x4h0000gn/T/ipykernel_53394/3336101104.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SAA_1['Date'] = pd.to_datetime(SAA_1['Date'])
# /var/folders/m7/tssqlvyd6qg7dyx5bvdn0x4h0000gn/T/ipykernel_53394/3336101104.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SAA_1['Shift_Date'] = SAA_1['Date'] + pd.Timedelta(days=1)
#               State       Date  TestsReported Shift_Date  SAA_t_1_scalar
# 0           Alabama 2020-04-12           2165 2020-04-13             NaN
# 1         Louisiana 2020-04-12           1914 2020-04-13             NaN
# 2           Arizona 2020-04-12           1119 2020-04-13             NaN
# 3      Rhode Island 2020-04-12           1059 2020-04-13             NaN
# 4          Maryland 2020-04-12           3015 2020-04-13             NaN
# ...             ...        ...            ...        ...             ...
# 7171  New Hampshire 2020-08-27           3952 2020-08-28         19515.0
# 7172         Nevada 2020-08-27           7673 2020-08-28         19515.0
# 7173       Nebraska 2020-08-27           5925 2020-08-28         19515.0
# 7174         Oregon 2020-08-27           6098 2020-08-28         19515.0
# 7175        Wyoming 2020-08-27            502 2020-08-28         19515.0
#
# [7176 rows x 5 columns]

# %%
# Vector SAA t-1
SAA_1.sort_values(by=['State', 'Date'], inplace=True)
SAA_1['SAA_t_1_vector'] = SAA_1.groupby('State')['TestsReported'].shift(1)
SAA_1.sort_index(axis=0, inplace=True)
SAA_1
# Out:
#               State       Date  TestsReported Shift_Date  SAA_t_1_scalar  \
# 0           Alabama 2020-04-12           2165 2020-04-13             NaN
# 1         Louisiana 2020-04-12           1914 2020-04-13             NaN
# 2           Arizona 2020-04-12           1119 2020-04-13             NaN
# 3      Rhode Island 2020-04-12           1059 2020-04-13             NaN
# 4          Maryland 2020-04-12           3015 2020-04-13             NaN
# ...             ...        ...            ...        ...             ...
# 7171  New Hampshire 2020-08-27           3952 2020-08-28         19515.0
# 7172         Nevada 2020-08-27           7673 2020-08-28         19515.0
# 7173       Nebraska 2020-08-27           5925 2020-08-28         19515.0
# 7174         Oregon 2020-08-27           6098 2020-08-28         19515.0
# 7175        Wyoming 2020-08-27            502 2020-08-28         19515.0
#
#       SAA_t_1_vector
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 7171          4619.0
# 7172          5516.0
# 7173          5288.0
# 7174          7248.0
# 7175          4549.0
#
# [7176 rows x 6 columns]

# %%
# Remove t_0 as only NaN SAA prescritions
#SAA_1.dropna(inplace=True)

# %%
SAA_1
# Out:
#               State       Date  TestsReported Shift_Date  SAA_t_1_scalar  \
# 0           Alabama 2020-04-12           2165 2020-04-13             NaN
# 1         Louisiana 2020-04-12           1914 2020-04-13             NaN
# 2           Arizona 2020-04-12           1119 2020-04-13             NaN
# 3      Rhode Island 2020-04-12           1059 2020-04-13             NaN
# 4          Maryland 2020-04-12           3015 2020-04-13             NaN
# ...             ...        ...            ...        ...             ...
# 7171  New Hampshire 2020-08-27           3952 2020-08-28         19515.0
# 7172         Nevada 2020-08-27           7673 2020-08-28         19515.0
# 7173       Nebraska 2020-08-27           5925 2020-08-28         19515.0
# 7174         Oregon 2020-08-27           6098 2020-08-28         19515.0
# 7175        Wyoming 2020-08-27            502 2020-08-28         19515.0
#
#       SAA_t_1_vector
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 7171          4619.0
# 7172          5516.0
# 7173          5288.0
# 7174          7248.0
# 7175          4549.0
#
# [7176 rows x 6 columns]

# %%
#SAA_1.to_csv('data/prescription/saa_t_1.csv', index=None)

# %% [markdown]
# ## SAA cumul: SAA prescription with cumulative training data

# %%
SAA_1 = saa.copy()

# %%
# Scalar SAA cumul

SAA_1['Day_before'] = SAA_1['Date'] + pd.Timedelta(days=-1)
n = len(SAA_1[SAA_1.Date == '2020-04-12'])
cumulative_average_per_date = SAA_1.groupby('Date')['TestsReported'].sum().rename('SAA_cumul_scalar')/n
cumulative_average_per_date.reset_index()
SAA_1 = SAA_1.merge(cumulative_average_per_date, left_on ='Day_before', right_on='Date', how='left')
SAA_1
# Out:
#               State       Date  TestsReported Shift_Date  SAA_t_1_scalar  \
# 0           Alabama 2020-04-12           2165 2020-04-13             NaN
# 1         Louisiana 2020-04-12           1914 2020-04-13             NaN
# 2           Arizona 2020-04-12           1119 2020-04-13             NaN
# 3      Rhode Island 2020-04-12           1059 2020-04-13             NaN
# 4          Maryland 2020-04-12           3015 2020-04-13             NaN
# ...             ...        ...            ...        ...             ...
# 7171  New Hampshire 2020-08-27           3952 2020-08-28         19515.0
# 7172         Nevada 2020-08-27           7673 2020-08-28         19515.0
# 7173       Nebraska 2020-08-27           5925 2020-08-28         19515.0
# 7174         Oregon 2020-08-27           6098 2020-08-28         19515.0
# 7175        Wyoming 2020-08-27            502 2020-08-28         19515.0
#
#       SAA_t_1_vector Day_before  SAA_cumul_scalar
# 0                NaN 2020-04-11               NaN
# 1                NaN 2020-04-11               NaN
# 2                NaN 2020-04-11               NaN
# 3                NaN 2020-04-11               NaN
# 4                NaN 2020-04-11               NaN
# ...              ...        ...               ...
# 7171          4619.0 2020-08-26      19515.269231
# 7172          5516.0 2020-08-26      19515.269231
# 7173          5288.0 2020-08-26      19515.269231
# 7174          7248.0 2020-08-26      19515.269231
# 7175          4549.0 2020-08-26      19515.269231
#
# [7176 rows x 8 columns]

# %%
### df for SAA cumulative prescription

# vectoral SAA cumul

cumulative_sum_per_state = SAA_1.groupby('State')['TestsReported'].cuan() - SAA_1['TestsReported']
cumulative_sum_per_state
SAA_1['SAA_cumul_vector'] = cumulative_sum_per_state
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/valentinbrekke/Desktop/Fall 23 - MIT/ML/Project/temporal_prescriptive_analysis/models_valent.ipynb Cellule 17 line 5
#       <a href='vscode-notebook-cell:/Users/valentinbrekke/Desktop/Fall%2023%20-%20MIT/ML/Project/temporal_prescriptive_analysis/models_valent.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> ### df for SAA cumulative prescription
#       <a href='vscode-notebook-cell:/Users/valentinbrekke/Desktop/Fall%2023%20-%20MIT/ML/Project/temporal_prescriptive_analysis/models_valent.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell:/Users/valentinbrekke/Desktop/Fall%2023%20-%20MIT/ML/Project/temporal_prescriptive_analysis/models_valent.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> # vectoral SAA cumul
# ----> <a href='vscode-notebook-cell:/Users/valentinbrekke/Desktop/Fall%2023%20-%20MIT/ML/Project/temporal_prescriptive_analysis/models_valent.ipynb#X42sZmlsZQ%3D%3D?line=4'>5</a> cumulative_sum_per_state = SAA_1.groupby('State')['TestsReported'].cummean() - SAA_1['TestsReported']
#       <a href='vscode-notebook-cell:/Users/valentinbrekke/Desktop/Fall%2023%20-%20MIT/ML/Project/temporal_prescriptive_analysis/models_valent.ipynb#X42sZmlsZQ%3D%3D?line=5'>6</a> cumulative_sum_per_state
#       <a href='vscode-notebook-cell:/Users/valentinbrekke/Desktop/Fall%2023%20-%20MIT/ML/Project/temporal_prescriptive_analysis/models_valent.ipynb#X42sZmlsZQ%3D%3D?line=6'>7</a> SAA_1['SAA_cumul_vector'] = cumulative_sum_per_state
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1312, in GroupBy.__getattr__(self, attr)
#    1309 if attr in self.obj:
#    1310     return self[attr]
# -> 1312 raise AttributeError(
#    1313     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1314 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'cummean'

# %%
SAA_1
# Out:
#               State       Date  TestsReported Shift_Date  SAA_t_1_scalar  \
# 0           Alabama 2020-04-12           2165 2020-04-13             NaN
# 1         Louisiana 2020-04-12           1914 2020-04-13             NaN
# 2           Arizona 2020-04-12           1119 2020-04-13             NaN
# 3      Rhode Island 2020-04-12           1059 2020-04-13             NaN
# 4          Maryland 2020-04-12           3015 2020-04-13             NaN
# ...             ...        ...            ...        ...             ...
# 7171  New Hampshire 2020-08-27           3952 2020-08-28         19515.0
# 7172         Nevada 2020-08-27           7673 2020-08-28         19515.0
# 7173       Nebraska 2020-08-27           5925 2020-08-28         19515.0
# 7174         Oregon 2020-08-27           6098 2020-08-28         19515.0
# 7175        Wyoming 2020-08-27            502 2020-08-28         19515.0
#
#       SAA_t_1_vector Day_before  SAA_cumul_scalar  SAA_cumul_vector
# 0                NaN 2020-04-11               NaN                 0
# 1                NaN 2020-04-11               NaN                 0
# 2                NaN 2020-04-11               NaN                 0
# 3                NaN 2020-04-11               NaN                 0
# 4                NaN 2020-04-11               NaN                 0
# ...              ...        ...               ...               ...
# 7171          4619.0 2020-08-26      19515.269231            306940
# 7172          5516.0 2020-08-26      19515.269231            766374
# 7173          5288.0 2020-08-26      19515.269231            534360
# 7174          7248.0 2020-08-26      19515.269231            750317
# 7175          4549.0 2020-08-26      19515.269231            122055
#
# [7176 rows x 9 columns]

# %%
SAA_1[100:150]
# Out:
#                     State       Date  TestsReported Shift_Date  \
# 100               Vermont 2020-04-13            398 2020-04-14
# 101              Arkansas 2020-04-13            293 2020-04-14
# 102              Illinois 2020-04-13           5728 2020-04-14
# 103              Delaware 2020-04-13            767 2020-04-14
# 104                  Utah 2020-04-14           6461 2020-04-15
# 105          South Dakota 2020-04-14              0 2020-04-15
# 106               Florida 2020-04-14          14621 2020-04-15
# 107               Montana 2020-04-14            730 2020-04-15
# 108             Minnesota 2020-04-14             56 2020-04-15
# 109                Kansas 2020-04-14           1091 2020-04-15
# 110                  Iowa 2020-04-14             83 2020-04-15
# 111              Colorado 2020-04-14             91 2020-04-15
# 112              Virginia 2020-04-14           1931 2020-04-15
# 113                Alaska 2020-04-14            398 2020-04-15
# 114              Kentucky 2020-04-14            631 2020-04-15
# 115              Oklahoma 2020-04-14            895 2020-04-15
# 116                Oregon 2020-04-14           1928 2020-04-15
# 117          Pennsylvania 2020-04-14           6044 2020-04-15
# 118  District of Columbia 2020-04-14            479 2020-04-15
# 119              Missouri 2020-04-14           2374 2020-04-15
# 120        North Carolina 2020-04-14           2568 2020-04-15
# 121           Connecticut 2020-04-14           1995 2020-04-15
# 122           Mississippi 2020-04-14           2404 2020-04-15
# 123                 Idaho 2020-04-14            916 2020-04-15
# 124             Tennessee 2020-04-14           4492 2020-04-15
# 125             Wisconsin 2020-04-14           1790 2020-04-15
# 126                 Maine 2020-04-14            632 2020-04-15
# 127              New York 2020-04-14          19713 2020-04-15
# 128              Illinois 2020-04-14           6575 2020-04-15
# 129               Wyoming 2020-04-14              0 2020-04-15
# 130         New Hampshire 2020-04-14            337 2020-04-15
# 131               Georgia 2020-04-14           5491 2020-04-15
# 132              Delaware 2020-04-14            720 2020-04-15
# 133              Arkansas 2020-04-14            780 2020-04-15
# 134               Vermont 2020-04-14            446 2020-04-15
# 135              Maryland 2020-04-14           3961 2020-04-15
# 136          North Dakota 2020-04-14            520 2020-04-15
# 137            Washington 2020-04-14           4186 2020-04-15
# 138            New Jersey 2020-04-14            499 2020-04-15
# 139          Rhode Island 2020-04-14           1664 2020-04-15
# 140                 Texas 2020-04-14           4379 2020-04-15
# 141               Arizona 2020-04-14           2575 2020-04-15
# 142               Indiana 2020-04-14           5328 2020-04-15
# 143                Nevada 2020-04-14            742 2020-04-15
# 144               Alabama 2020-04-14           2942 2020-04-15
# 145              Michigan 2020-04-14           6097 2020-04-15
# 146         Massachusetts 2020-04-14           7056 2020-04-15
# 147        South Carolina 2020-04-14           1456 2020-04-15
# 148              Nebraska 2020-04-14           1152 2020-04-15
# 149            New Mexico 2020-04-14            591 2020-04-15
#
#      SAA_t_1_scalar  SAA_t_1_vector Day_before  SAA_cumul_scalar  \
# 100          2151.0           471.0 2020-04-12       2151.384615
# 101          2151.0           625.0 2020-04-12       2151.384615
# 102          2151.0          3198.0 2020-04-12       2151.384615
# 103          2151.0           496.0 2020-04-12       2151.384615
# 104          2193.0          3521.0 2020-04-13       2193.000000
# 105          2193.0             0.0 2020-04-13       2193.000000
# 106          2193.0         14472.0 2020-04-13       2193.000000
# 107          2193.0           314.0 2020-04-13       2193.000000
# 108          2193.0            85.0 2020-04-13       2193.000000
# 109          2193.0           516.0 2020-04-13       2193.000000
# 110          2193.0            54.0 2020-04-13       2193.000000
# 111          2193.0            50.0 2020-04-13       2193.000000
# 112          2193.0          1439.0 2020-04-13       2193.000000
# 113          2193.0           399.0 2020-04-13       2193.000000
# 114          2193.0           532.0 2020-04-13       2193.000000
# 115          2193.0           842.0 2020-04-13       2193.000000
# 116          2193.0          1540.0 2020-04-13       2193.000000
# 117          2193.0          3386.0 2020-04-13       2193.000000
# 118          2193.0           391.0 2020-04-13       2193.000000
# 119          2193.0          1465.0 2020-04-13       2193.000000
# 120          2193.0          1278.0 2020-04-13       2193.000000
# 121          2193.0          1680.0 2020-04-13       2193.000000
# 122          2193.0          1289.0 2020-04-13       2193.000000
# 123          2193.0           838.0 2020-04-13       2193.000000
# 124          2193.0          2207.0 2020-04-13       2193.000000
# 125          2193.0          1341.0 2020-04-13       2193.000000
# 126          2193.0           503.0 2020-04-13       2193.000000
# 127          2193.0         16270.0 2020-04-13       2193.000000
# 128          2193.0          5728.0 2020-04-13       2193.000000
# 129          2193.0           347.0 2020-04-13       2193.000000
# 130          2193.0           181.0 2020-04-13       2193.000000
# 131          2193.0          4603.0 2020-04-13       2193.000000
# 132          2193.0           767.0 2020-04-13       2193.000000
# 133          2193.0           293.0 2020-04-13       2193.000000
# 134          2193.0           398.0 2020-04-13       2193.000000
# 135          2193.0          2326.0 2020-04-13       2193.000000
# 136          2193.0           281.0 2020-04-13       2193.000000
# 137          2193.0          2255.0 2020-04-13       2193.000000
# 138          2193.0           502.0 2020-04-13       2193.000000
# 139          2193.0           467.0 2020-04-13       2193.000000
# 140          2193.0          5024.0 2020-04-13       2193.000000
# 141          2193.0           947.0 2020-04-13       2193.000000
# 142          2193.0          2380.0 2020-04-13       2193.000000
# 143          2193.0           788.0 2020-04-13       2193.000000
# 144          2193.0          2626.0 2020-04-13       2193.000000
# 145          2193.0          4377.0 2020-04-13       2193.000000
# 146          2193.0          5881.0 2020-04-13       2193.000000
# 147          2193.0           733.0 2020-04-13       2193.000000
# 148          2193.0           520.0 2020-04-13       2193.000000
# 149          2193.0           853.0 2020-04-13       2193.000000
#
#      SAA_cumul_vector
# 100               471
# 101               625
# 102              3198
# 103               496
# 104              5235
# 105                 0
# 106             18990
# 107               746
# 108               113
# 109              1131
# 110               111
# 111                60
# 112              3769
# 113               661
# 114              1253
# 115              2018
# 116              3004
# 117              8881
# 118               938
# 119              2658
# 120              2468
# 121              4383
# 122              2775
# 123              1751
# 124              5597
# 125              2562
# 126               852
# 127             34747
# 128              8926
# 129               347
# 130               585
# 131              5734
# 132              1263
# 133               918
# 134               869
# 135              5341
# 136               499
# 137              6216
# 138               724
# 139              1526
# 140             13905
# 141              2066
# 142              5170
# 143              2132
# 144              4791
# 145              7758
# 146             13102
# 147              1541
# 148              1213
# 149              2774
